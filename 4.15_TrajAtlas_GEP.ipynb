# %%
import sys
sys.path.append("../../limb/TrajAtlas/TrajAtlas/utils/")
sys.path.append("../../limb/TrajAtlas/")
import TrajAtlas

# %%
import scanpy as sc
import pandas as pd

# %%
adata = sc.read_h5ad("../important_processed_data/4.15_cNMF.h5ad")

# %%
adata.var["cNMF_pattern"]
# Out:
# Xkr4       pattern1
# Rp1        pattern2
# Sox17      pattern6
# Lypla1     pattern2
# Tcea1      pattern2
#              ...
# Acr        pattern6
# Cpn2       pattern4
# Tm4sf19    pattern4
# Trat1      pattern6
# Cc2d2b     pattern1
# Name: cNMF_pattern, Length: 12787, dtype: category
# Categories (7, object): ['pattern1', 'pattern2', 'pattern3', 'pattern4', 'pattern5', 'pattern6', 'pattern7']

# %%
varDf
# Out:
# Xkr4                                                pattern1
# Rp1                                                 pattern2
# Sox17                                               pattern6
# Lypla1                                              pattern2
# Tcea1                                               pattern2
#                                  ...
# Cpn2                                                pattern4
# Tm4sf19                                             pattern4
# Trat1                                               pattern6
# Cc2d2b                                              pattern1
# GENES      Index(['Xkr4', 'Rp1', 'Sox17', 'Lypla1', 'Tcea...
# Name: cNMF_pattern, Length: 12788, dtype: object

# %%
varDf = pd.DataFrame(adata.var["cNMF_pattern"].dropna())
varDf["GENES"] = varDf.index
featuredict = varDf.groupby('cNMF_pattern')['GENES'].apply(list).to_dict()
# Out:
# /tmp/ipykernel_4130375/639245216.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   featuredict = varDf.groupby('cNMF_pattern')['GENES'].apply(list).to_dict()

# %%
featuredict.keys()
# Out:
# dict_keys(['pattern1', 'pattern2', 'pattern3', 'pattern4', 'pattern5', 'pattern6', 'pattern7'])

# %%
featureDf=pd.DataFrame("pattern" + adata.var["pattern"].dropna().astype("int").astype("str"))
featureDf["GENES"]=featureDf.index
featuredict = dict(zip(featureDf['pattern'], featureDf['GENES'].tolist()))
featuredict = featureDf.groupby('pattern')['GENES'].apply(list).to_dict()

# %%
featureDf=pd.DataFrame("pattern" + adata.var["pattern"].dropna().astype("int").astype("str"))
featureDf["GENES"]=featureDf.index
featuredict = dict(zip(featureDf['pattern'], featureDf['GENES'].tolist()))
featuredict = featureDf.groupby('pattern')['GENES'].apply(list).to_dict()

# %%
import GEP as util

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 13056 × 12787
#     obs: 'nCount_RNA', 'nFeature_RNA', 'percent.mt', 'orig.ident', 'celltype', 'idents', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'point', 'pattern0', 'pattern1', 'pattern2', 'pattern3', 'pattern4', 'pattern5', 'pattern6', 'pattern7'
#     var: 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'pattern', 'membership', 'cNMF_pattern'
#     uns: 'log1p', 'orig.ident_colors'
#     obsm: 'X_umap', 'spatial'
#     layers: 'logcounts'

# %%
tvMap = util.getAttribute(adata,featureKey = "cNMF_pattern",sampleKey = "orig.ident")
# Out:
# ../../limb/TrajAtlas/TrajAtlas/utils/utils_spatial_1.py:86: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   featureDict = varDf.groupby(featureKey)['GENES'].apply(list).to_dict()
# 100%|██████████| 7/7 [00:00<00:00, 968.05it/s]
# /home/zhanglab/mambaforge/envs/celloracle/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /home/zhanglab/mambaforge/envs/celloracle/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# ...

# %%
varDf = pd.DataFrame(adata.var["cNMF_pattern"].dropna())
varDf["GENES"] = varDf.index
featureDict = varDf.groupby("cNMF_pattern")['GENES'].apply(list).to_dict()
# Out:
# /tmp/ipykernel_36061/1813734518.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   featureDict = varDf.groupby("cNMF_pattern")['GENES'].apply(list).to_dict()

# %%
featureDict
# Out:
# {'pattern1': ['Xkr4',
#   'Rgs20',
#   'Atp6v1h',
#   'Rb1cc1',
#   'Pcmtd1',
#   'Arfgef1',
#   'Cpa6',
#   'A830018L16Rik',
#   'Slco5a1',
#   'Ncoa2',
#   'Lactb2',
#   'Eya1',
#   'Stau2',
#   'Ube2w',
#   'Kcnq5',
#   'Smap1',
#   'Fam135a',
#   'Adgrb3',
#   'Bag2',
#   'Zfp451',
#   'Ccdc115',
#   'Arhgef4',
#   'Uggt1',
#   'Tmem131',
#   'Inpp4a',
#   'Tbc1d8',
#   'Map4k4',
#   'Il1rl2',
#   'Tgfbrap1',
#   'Tmeff2',
#   'Stat1',
#   'Nab1',
#   'Mfsd6',
#   'Pgap1',
#   'Ankrd44',
#   'Mob4',
#   'Bzw1',
#   'Fam126b',
#   'Casp8',
#   'Bmpr2',
#   'Fam117b',
#   'Carf',
#   'Abi2',
#   'Ctla4',
#   'Pard3b',
#   'Plekhm3',
#   'Idh1',
#   'Pikfyve',
#   'Map2',
#   'Rpe',
#   'Lancl1',
#   'Mreg',
#   'Rnf25',
#   'Ttll4',
#   'Epha4',
#   'Farsb',
#   'Ap1s3',
#   'Wdfy1',
#   'Cul3',
#   'Rhbdd1',
#   'Agfg1',
#   'Slc19a3',
#   'Trip12',
#   'Dis3l2',
#   'Gigyf2',
#   'Atg16l1',
#   'Usp40',
#   'Ugt1a6a',
#   'Agap1',
#   'Hes6',
#   'Per2',
#   'Hdac4',
# ...

# %%
df = util._getAttributeFun(adata,featureDict = featureDict,patternKey =["pattern1"],njobs=1)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 100%|██████████| 1/1 [00:31<00:00, 31.23s/it]

# %%
tvMap = util.getAttributeGEP(adata,featureKey = "cNMF_pattern",sampleKey = "orig.ident",patternKey=["pattern1"],njobs=1)
# Out:
# ../../limb/TrajAtlas/TrajAtlas/utils/GEP.py:112: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   featureDict = varDf.groupby(featureKey)['GENES'].apply(list).to_dict()
#
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#
# ...
#   0%|          | 0/8 [06:21<?, ?it/s]
#
#
#  29%|██▊       | 2/7 [01:39<04:22, 52.40s/it]
#
#  43%|████▎     | 3/7 [01:49<02:11, 32.98s/it]
#
#  57%|█████▋    | 4/7 [02:18<01:34, 31.44s/it]
#
#  71%|███████▏  | 5/7 [02:30<00:48, 24.36s/it]
#
#  86%|████████▌ | 6/7 [02:48<00:22, 22.32s/it]
#
# ...
# 100%|██████████| 7/7 [00:36<00:00,  5.16s/it]
# /home/zhanglab/mambaforge/envs/celloracle/lib/python3.9/site-packages/pandas/core/internals/blocks.py:393: RuntimeWarning: invalid value encountered in sqrt
#   result = func(self.values, **kwargs)
# ...

# %%
tvMap
# Out:
# MuData object with n_obs × n_vars = 6 × 38361
#   3 modalities
#     corr:	6 x 12787
#       layers:	'mod'
#     expr:	6 x 12787
#       layers:	'mod'
#     peak:	6 x 12787
#       layers:	'mod'
